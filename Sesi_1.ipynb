# %% [markdown]
# # Sesi 1
#
# Introduction, Data Types, and Variables
#
# 1. Introduction
# 2. Data Types
# 3. Variables
#
# - Introduction
# - Data Types
# - Variables

# %% [markdown]
# ## Integers

# %%
print(123123)
# Out:
# 123123

# %%
print(10)
# Out:
# 10

# %%
print(type(10))
# Out:
# <class 'int'>

# %% [markdown]
# ## Floating Point

# %%
print(4.2)
# Out:
# 4.2

# %%
print(4.)
# Out:
# 4.0

# %%
print(.2)
# Out:
# 0.2

# %%
print(.4e7)
# Out:
# 4000000.0

# %%
print(4.2e-4)
# Out:
# 0.00042

# %%
print(type(4.2))
# Out:
# <class 'float'>

# %% [markdown]
# ## String

# %%
print('raka')
# Out:
# raka

# %%
print(type('hacktiv8'))
# Out:
# <class 'str'>

# %%
print(type(4.2))
print(type('4.2'))
# Out:
# <class 'float'>
# <class 'str'>

# %% [markdown]
# ## Boolean

# %%
print(True)
print(False)
# Out:
# True
# False

# %%
print(type(True))
print(type('True'))
# Out:
# <class 'bool'>
# <class 'str'>

# %% [markdown]
# ## Variables

# %%
kotak_donat = 5

# %%
print(kotak_donat)
# Out:
# 5

# %%
kotak_donat = 7
print(kotak_donat)
# Out:
# 7

# %%
kotak_1 = kotak_2 = kotak_3 = 3
print(kotak_1, kotak_2, kotak_3)
# Out:
# 3 3 3

# %%
kotak_donat
# Out:
# 7

# %%
sembilan_bola_naga = 9

# %% [markdown]
# ## Arithmetic Operators

# %%
a = 4
b = 3

# %%
print(a + b)
# Out:
# 7

# %%
a - b
# Out:
# 1

# %%
a * b
# Out:
# 12

# %%
a / b
# Out:
# 1.3333333333333333

# %%
4 / 2
# Out:
# 2.0

# %% [markdown]
# ## Comparison Operators

# %%
c = 10
d = 20

# %%
c == d
# Out:
# False

# %%
c != d
# Out:
# True

# %%
c <= d
# Out:
# True

# %%
c >= d
# Out:
# False

# %% [markdown]
# ## String Manipulation

# %%
s = 'foo'
t = 'bar'

# %%
s + t
# Out:
# 'foobar'

# %%
print('Hacktiv ' + 'GIT')
# Out:
# Hacktiv GIT

# %%
s * 4
# Out:
# 'foofoofoofoo'

# %%
s
# Out:
# 'foo'

# %%
s in 'That food is for us'
# Out:
# True

# %%
s in t
# Out:
# False

# %%
'foo' in 'That is good for us'
# Out:
# False

# %%
z = 'HackTIV8 jakarta'

print(z.capitalize())
# Out:
# Hacktiv8 jakarta

# %%
z.lower()
# Out:
# 'hacktiv8'

# %%
z.swapcase()
# Out:
# 'hACKtiv8'

# %%
z.title()
# Out:
# 'Hacktiv8 Jakarta'

# %%
z.upper()
# Out:
# 'HACKTIV8 JAKARTA'

# %% [markdown]
# ## List

# %%
barangDiKamar = ['kasur', 'meja', 'lukisan', 'lampu']

# %%
barangDiKamar
# Out:
# ['kasur', 'meja', 'lukisan', 'lampu']

# %%
a = [21.41, 'foo', 3, False]
print(a)
# Out:
# [21.41, 'foo', 3, False]

# %%
barangDiKamar[1]
# Out:
# 'meja'

# %%
barangDiKamar[0]
# Out:
# 'kasur'

# %%
barangDiKamar[-1]
# Out:
# 'lampu'

# %%
barangDiKamar[-2]
# Out:
# 'lukisan'

# %%
a = ['foo', 'bar', 'baz', 'qux', 'quux', 'corge']

# %%
a[2:5]
# Out:
# ['baz', 'qux', 'quux']

# %%
a[3:5]
# Out:
# ['qux', 'quux']

# %%
a[1:3]
# Out:
# ['bar', 'baz']

# %%
a[4:]
# Out:
# ['quux', 'corge']

# %%
a[:4]
# Out:
# ['foo', 'bar', 'baz', 'qux']

# %%
a[:]
# Out:
# ['foo', 'bar', 'baz', 'qux', 'quux', 'corge']

# %%
barangDiKamar + ['kulkas', 'lemari pakaian']
# Out:
# ['kasur', 'meja', 'lukisan', 'lampu', 'kulkas', 'lemari pakaian']

# %%
barangDiKamar * 2
# Out:
# ['kasur', 'meja', 'lukisan', 'lampu', 'kasur', 'meja', 'lukisan', 'lampu']

# %%
len(barangDiKamar)
# Out:
# 4

# %%
min(barangDiKamar)
# Out:
# 'kasur'

# %%
max(barangDiKamar)
# Out:
# 'meja'

# %%
barangDiKamar
# Out:
# ['kasur', 'meja', 'lukisan', 'lampu']

# %%
barangDiKamar[2] = 'lemari pakaian'

# %%
barangDiKamar
# Out:
# ['kasur', 'meja', 'lemari pakaian', 'lampu']

# %%
del barangDiKamar[-1]

# %%
barangDiKamar
# Out:
# ['kasur', 'meja', 'lemari pakaian']

# %%
['kasur', 'meja', ['kemeja', 'kaos', 'shorts']]
# Out:
# ['kasur', 'meja', ['kemeja', 'kaos', 'shorts']]

# %% [markdown]
# ## Tuples

# %%
namaBulanAwal = ('januari', 'februari', 'maret')

# %%
namaBulanAwal
# Out:
# ('januari', 'februari', 'maret')

# %%
namaBulanAwal[1]
# Out:
# 'februari'

# %%
namaBulanAwal[1] = 'april'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-417333d3925f> in <module>
# ----> 1 namaBulanAwal[1] = 'april'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## Dictionary

# %%
identitas = {'nama': 'Raka',
             'alamat': 'Jakarta',
             'email': 'mail@mail.com'}

# %%
identitas
# Out:
# {'nama': 'Raka', 'alamat': 'Jakarta', 'email': 'mail@mail.com'}

# %%
identitas['nama']
# Out:
# 'Raka'

# %%
identitas['alamat']
# Out:
# 'Jakarta'

# %%
# adding new value
identitas['noHP'] = '0812345678'

# %%
identitas
# Out:
# {'nama': 'Raka',
#  'alamat': 'Jakarta',
#  'email': 'mail@mail.com',
#  'noHP': '0812345678'}

# %%
identitas['noHP']
# Out:
# '0812345678'

# %%
# modify a value
identitas['noHP'] = '0823456789'

# %%
identitas
# Out:
# {'nama': 'Raka',
#  'alamat': 'Jakarta',
#  'email': 'mail@mail.com',
#  'noHP': '0823456789'}

# %%
# delete a value
del identitas['noHP']

# %%
identitas
# Out:
# {'nama': 'Raka', 'alamat': 'Jakarta', 'email': 'mail@mail.com'}

# %%
identitas.items()
# Out:
# dict_items([('nama', 'Raka'), ('alamat', 'Jakarta'), ('email', 'mail@mail.com')])

# %%
identitas.keys()
# Out:
# dict_keys(['nama', 'alamat', 'email'])

# %%
identitas.values()
# Out:
# dict_values(['Raka', 'Jakarta', 'mail@mail.com'])
